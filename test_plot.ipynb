# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg')

# %% [markdown]
# ## Data

# %%
angs_1 = pd.read_csv("data/Ang_CA2D_Iv2D.csv")
angs_2 = pd.read_csv("data/Ang_CA2D_Iv3D.csv")
angs_3 = pd.read_csv("data/Ang_Iv3D_a50.csv")
# Out:
#     CellSize  Angle
# 0        1.0   20.5
# 1        2.5   20.5
# 2        5.0   20.2
# 3        7.5   19.5
# 4       10.0   19.2
# 5       25.0   18.8
# 6       30.0   18.5
# 7       35.0   17.5
# 8       40.0   17.2
# 9       45.0   17.0
# 10      50.0   16.0
# 11      55.0   16.0
# 12      60.0   15.9
# 13      65.0   15.8
# 14      70.0   15.6
# 15      75.0   15.5
# 16     100.0   12.5
# 17     250.0    9.0
# 18     500.0    8.0
# 19     750.0    8.0
# 20    1000.0    8.0

# %% [markdown]
# ## Plot #1

# %%
fig = plt.figure(figsize=(12, 5), dpi=100)
x1, y1 = angs_1["CellSize"], angs_1["Angle"]
x2, y2 = angs_2["CellSize"], angs_2["Angle"]
x3, y3 = angs_3["CellSize"], angs_3["Angle"]

ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

# ax1
ax1.plot(
    x1, 
    y1, 
    "o", 
    label="CA2D_Iv2D",
    markersize=10,
    markerfacecolor="red",
    markeredgecolor="black",
    alpha=0.5
)

ax1.plot(
    x2, 
    y2, 
    "o", 
    label="CA2D_Iv3D"
    markersize=10,
    markerfacecolor="green",
    markeredgecolor="black",
    alpha=0.5
)

ax1.semilogx()
ax1.set_title("GB Angle vs. Cell Size")
ax1.set_xlabel("Cell size, [µm]", fontsize=12)
ax1.set_ylabel("GB angle, [°]", fontsize=12)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=3, handletextpad=0, columnspacing=0.1)

ax1.set_ylim(0, 25, auto=True)
ax1.tick_params(labelsize=12)
ax1.yaxis.set_minor_locator(AutoMinorLocator())
ax1.grid()

ax1.axvline(33.6, color='royalblue', linestyle='--', linewidth=1)
ax1.axvline(72.1, color='royalblue', linestyle='--', linewidth=1)
ax1.axvline(56.6, color='springgreen', linestyle='--', linewidth=1)
ax1.axvline(115.8, color='springgreen', linestyle='--', linewidth=1)

# ax2
ax2.plot(
    x3, 
    y3, 
    "o", 
    markersize=10,
    markerfacecolor="blue",
    markeredgecolor="black",
    alpha=0.5
)

ax2.semilogx()
ax2.set_title("GB Angle vs. Cell Size")
ax2.set_xlabel("Cell size, [µm]", fontsize=12)
ax2.set_ylabel("GB angle, [°]", fontsize=12)

ax2.set_ylim(0, 25, auto=True)
ax2.tick_params(labelsize=12)
ax2.yaxis.set_minor_locator(AutoMinorLocator())
ax2.grid()

ax2.axvline(33.6, color='royalblue', linestyle='--', linewidth=1)
ax2.axvline(72.1, color='royalblue', linestyle='--', linewidth=1)
ax2.axvline(56.6, color='springgreen', linestyle='--', linewidth=1)
ax2.axvline(115.8, color='springgreen', linestyle='--', linewidth=1)

# save
plt.savefig("outputs/my_fig.png", bbox_inches='tight', pad_inches=0.025)
